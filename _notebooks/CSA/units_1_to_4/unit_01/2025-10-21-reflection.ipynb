# %% [markdown]
# ---
# layout: post
# toc: true
# title: Blog/Retrospection
# menu: nav/CSA_Nunits/csaunit1.html
# permalink: /csa/neil_blog
# author: Neil Chandra
# ---

# %%
Blog/Retrospective could do the following...

Compare yourself to the beginning of the year
Remember key things from 3 sprints (Tools, Fundamentals of JavaScript/Python,  Profile/LinkedIn quest.
How N@tM went?  Did you get a comment or two you liked?
What do you want to do next on project, given time?
What do you want to learn next in CompSci?
Analytics review.
MCQ review, score, correction, and approach
Something cool you'd like to share.

# %% [markdown]
# ## My Blog/Retrospection for CSA Trimester 1 Final Review

# %% [markdown]
# ### Comparison to beginning of the year
# > Overall, I definitely improved throughout the year, improving my CSA knowledge.
# > However, I'm sure everyone improved
# > Let me be more specific
# > I took AP CSP last year, and I got very sick halfway through the year, leading me to miss a lot of AP CSP. Completing AP CSA Trimester 1 meant learning everything from this trimester, as well as some of the basic AP CSP principles from last year.
# > I improved my skills of collaboration, as this time, we were forced to work in larger groups.

# %% [markdown]
# ### 3 Key things from Sprints
# > - Using classes and objects
# > - Loops and conditionals
# > - Using spring for the backend.

# %% [markdown]
# ### N@TM Experience
# > I had fun with my group, and we were able to present to multiple people, both parents and other students, and overall, I think it was a great way to show off our progress as well as what we have learned this trimester.
# > We got a lot of comments on our project, most of them were good, and the majority of them commented on our design and API content, however, some of them commented on our presentation (likely due to N@TM being a little cluttered)
# > We also got some troll comments lol.
#
# [Link](https://docs.google.com/document/d/1Dhw5j8JEDbvBfbCW493GVsmwJPe878x5gep6LXfkrvY/edit?tab=t.0)

# %% [markdown]
# ### Next Steps for Project
# > I think that, in the future we could have improved the layout and styling of our CSA + Resume building modules, creating a more user friendly design.

# %% [markdown]
# ### What I want to learn next in CSA
# > Next:
# > - I want to learn more about object-oriented programming in Java, especially how to use classes, objects, and inheritance.
# > - I’m also interested in working with ArrayLists and learning how to solve problems using loops, conditionals, and methods.

# %% [markdown]
# ### Analytics
# Go to [Link](https://pages.opencodingsociety.com/dashboard) to show Analytics for your profile

# %% [markdown]
# ### MCQ Review
# > I approached the MCQ as a practice for the AP Exam in Trimester 3, I believe that it is very good practice as it effectively simulates the kind of questions that will be asked. However, my score indicates that I have a lot to improve on throughout the year.
#
# Go to the MCQ on collegeboard
# [Link](https://apclassroom.collegeboard.org/8/assignments?status=completed)
#
# Talk about Performance
# [Link](https://apclassroom.collegeboard.org/8/assessments/results/71349753/performance)
#
# > Overall, the majority of the questions that I got wrong were in units 2 and 3. These appear to be weak spots, indicating that I may have to improve my understanding of selection and iteration, and class creation.

# %% [markdown]
# ### Something cool
# I dont have a drivers licence, and I used to be allergic to cashews.
